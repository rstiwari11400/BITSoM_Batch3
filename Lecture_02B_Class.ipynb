# %% [markdown]
# # Dictionaries — Basics

# %% [markdown]
# ### Why dictionaries?
# Lists use positions. Dictionaries use names, called keys.

# %%
apple = ['Apple', 100, 20, 'Kg']
print(apple[0])  # name
print(apple[1])  # price
# Out:
# Apple
# 100

# %%
apple = {
    'name': 'Apple',
    'price': 100,
    'quantity': 20,
    'unit': 'Kg'
}
print(type(apple))
# Out:
# <class 'dict'>

# %%
apple['Available'] = True

# %%
apple
# Out:
# {'name': 'Apple', 'price': 120, 'quantity': 20, 'Available': True}

# %% [markdown]
# ### Access values

# %%
print('Name:', apple['name'])
print('Price:', apple['price'])
# Out:
# Name: Apple
# Price: 100

# %%
print(apple.get('quantity'))
print(apple.get('discount'))
# Out:
# 20
# None

# %% [markdown]
# ### Update values

# %%
apple['price'] = 120
print(apple)
# Out:
# {'name': 'Apple', 'price': 120, 'quantity': 20, 'unit': 'Kg'}

# %% [markdown]
# ### Add new key-value pairs

# %%
apple['available'] = True
print(apple)
# Out:
# {'name': 'Apple', 'price': 120, 'quantity': 20, 'unit': 'Kg', 'available': True}

# %% [markdown]
# ### Remove key-value pairs

# %%
removed_value = apple.pop('unit')
print(apple)
print(removed_value)
# Out:
# {'name': 'Apple', 'price': 120, 'quantity': 20}
# Kg

# %% [markdown]
# ### Check if a key exists

# %%
print('price' in apple)
print('discount' in apple)
# Out:
# True
# False

# %% [markdown]
# ### Keys, values, and items

# %%
apple
# Out:
# {'name': 'Apple', 'price': 120, 'quantity': 20}

# %%
print(apple.keys())
print(apple.values())
print(apple.items())
# Out:
# dict_keys(['name', 'price', 'quantity'])
# dict_values(['Apple', 120, 20])
# dict_items([('name', 'Apple'), ('price', 120), ('quantity', 20)])

# %% [markdown]
# ### Loop through a dictionary

# %%
for key in apple.keys():
    print(key)
# Out:
# name
# price
# quantity

# %%
for item in apple.items():
    print(item[0], item[1])
# Out:
# name Apple
# price 120
# quantity 20

# %% [markdown]
# ### List of dictionaries

# %%
items = [
    {'name': 'Apple', 'price': 100, 'quantity': 20, 'unit': 'Kg'},
    {'name': 'Banana', 'price': 50, 'quantity': 10, 'unit': 'Kg'}
]
print(items)
# Out:
# [{'name': 'Apple', 'price': 100, 'quantity': 20, 'unit': 'Kg'}, {'name': 'Banana', 'price': 50, 'quantity': 10, 'unit': 'Kg'}]

# %%
print(items[0]['name'])
print(items[1]['price'])
# Out:
# Apple
# 50

# %%
for item in items:
    print(item['name'], item['price'])
# Out:
# Apple 100
# Banana 50
