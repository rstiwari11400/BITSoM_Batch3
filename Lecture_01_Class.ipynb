# %% [markdown]
# # Lecture 1 — Setup, Syntax, and Strings

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Setup & Environment

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# ## 2. Scripts & IDE Workflow

# %%
from hello import say_hello
say_hello('Amit')
# Out:
# Hello, Amit!

# %%
help(say_hello)
# Out:
# Help on function say_hello in module hello:
#
# say_hello(name)
#     Enter your name and this function will greet you.

# %% [markdown]
# ## 3. Variables, Types, and Naming

# %%
x= 5
y= "Rama4389438"
z= 3.14
ab = True

# %%
x=x+1
print(x)
# Out:
# 6

# %%
x-=1
print(x)
# Out:
# 5

# %%
print(x, y, z, ab, sep='\t')
# Out:
# 5	Rama4389438	3.14	True

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(x), type(y), type(z), type(ab), sep=', ')
# Out:
# <class 'int'>, <class 'str'>, <class 'float'>, <class 'bool'>

# %% [markdown]
# ## 4a. Numbers & Arithmetic

# %%
a=7
b=3
print('Addition---------------------------')
print(a + b)

print('Subtraction---------------------------')
print(a - b)

print('Multiplication---------------------------')
print(a * b)

print('Division---------------------------')
print(a / b)

print('Floor Division---------------------------')
print(a // b)

print('Modulus---------------------------')
print(a % b)

print('Exponentiation---------------------------')
print(2**5)
# Out:
# Addition---------------------------
# 10
# Subtraction---------------------------
# 4
# Multiplication---------------------------
# 21
# Division---------------------------
# 2.3333333333333335
# Floor Division---------------------------
# 2
# Modulus---------------------------
# 1
# Exponentiation---------------------------
# 32

# %% [markdown]
# # 4b. Boolean conditions and Logical

# %%
A=True
B=False

print('Logical AND---------------------------')
print(A and B)
print('Logical OR---------------------------')
print(A or B)
print('Logical NOT---------------------------')
print(not A)
# Out:
# Logical AND---------------------------
# False
# Logical OR---------------------------
# True
# Logical NOT---------------------------
# False

# %% [markdown]
# ## Boolean Operations
#
# Boolean operations work with the values `True` and `False`.
#
# ### AND
#
# The `and` operator returns `True` only when **both** conditions are `True`.
#
# | A | B | A and B |
# |---|---|---------|
# | True | True | True |
# | True | False | False |
# | False | True | False |
# | False | False | False |
#
# ### OR
#
# The `or` operator returns `True` when **at least one** condition is `True`.
#
# | A | B | A or B |
# |---|---|--------|
# | True | True | True |
# | True | False | True |
# | False | True | True |
# | False | False | False |
#
# ### NOT
#
# The `not` operator reverses a Boolean value.
#
# | A | not A |
# |---|-------|
# | True | False |
# | False | True |

# %%
A=5
A=A+1
A=7
B=4
print(A>B)
# Out:
# True

# %%
print(A)
# Out:
# 5

# %%
print('Comparison Operators---------------------------')
print('A > B:', A > B)
print('A < B:', A < B)
print('A >= B:', A >= B)
print('A <= B:', A <= B)
print('A == B:', A == B)
print('A != B:', A != B)
# Out:
# Comparison Operators---------------------------
# A > B: True
# A < B: False
# A >= B: True
# A <= B: False
# A == B: False
# A != B: True

# %% [markdown]
# ## 5. Strings — Building Blocks

# %%
s1 = 'Hello'
s2 = "World"


s3 = """Multi
Line String"""


print(s1+" "+s2)
print('------------------------')
print(s3)
# Out:
# Hello World
# ------------------------
# Multi
# Line String
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/rama/Desktop/BITSoM_Batch3/.venv/lib/python3.9/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/rama/Desktop/BITSoM_Batch3/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/rama/Desktop/BITSoM_Batch3/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/Users/rama/Desktop/BITSoM_Batch3/.venv/lib/python3.9/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list

# %% [markdown]
# # print space and new line

# %%
S="Python is awesome \nand you will love it."
print(S)
# Out:
# Python is awesome
# and you will love it.

# %% [markdown]
# # String slicing

# %%
sentence = 'Ramashankar Tiwari'
print('Print First Character---------------------------')
print(sentence[0])

print('Print Last Character---------------------------')    
print(sentence[-1])

print('get first four characters---------------------------')
print(sentence[0:4])

print('get characters from index 5 to 10---------------------------')
print(sentence[5:])

print('get alternate characters---------------------------')
print(sentence[:17:2])

print('get characters in reverse order---------------------------')
print(sentence[::-1])
# Out:
# Print First Character---------------------------
# R
# Print Last Character---------------------------
# i
# get first four characters---------------------------
# Rama
# get characters from index 5 to 10---------------------------
# hankar Tiwari
# get alternate characters---------------------------
# RmsakrTwr
# get characters in reverse order---------------------------
# irawiT raknahsamaR

# %% [markdown]
# ## 6. Strings — Transform & Clean

# %%
text = '  PyThOn Rocks  '
print(text.upper())
print(text.lower())
print(text.title())
print(text.swapcase())
# Out:
#   PYTHON ROCKS
#   python rocks
#   Python Rocks
#   pYtHoN rOCKS

# %%
print(text.strip())
# Out:
# PyThOn Rocks

# %%
date = '2024-11-11'
print(date.replace('-', '/'))

# %%
colors = 'red,green,blue'
print(colors.split(','))
sentence = 'Split on spaces'
print(sentence.split())

# %% [markdown]
# ## 7. Strings — Search & Inspect

# %%
message = 'hello python helloz'
print(message.find('python'))
print(message.find('java'))
print(message.rfind('hello'))
# Out:
# 6
# -1
# 13

# %%
filename = 'report.csv'
print(filename.startswith('Xep'))
print(filename.endswith('.csv'))
# Out:
# False
# True

# %% [markdown]
# ## 8. Strings — Formatting

# %%
name = 'Rama'
count = 5
print(f'Hello, {name}. You have {count} new messages.')
# Out:
# Hello, Rama. You have 5 new messages.

# %% [markdown]
# ## 9. Lists — Basics

# %%
my_list=[4, 'ArithmeticError', 3.14, True]
print(my_list)
print(type(my_list))

# %%
print(my_list[0], my_list[1], my_list[2], my_list[3])

# %%
nested_list = [1, 2, [3, 4], 5]
print(nested_list)

# %%
nested_list.append(4)
print(nested_list)

# %%
nested_list.insert(1, 1.5)
print(nested_list)

# %%
nested_list.append(1)
print(nested_list)

# %%
nested_list.remove(1)
print(nested_list)

# %%
popped = nested_list.pop()
print(nested_list, popped)

# %% [markdown]
# ## 10. Lists — Text Workflows

# %%
another_list = ['Banana', 'Apple', 'Mango']
print(another_list)

# %%
print(sorted(another_list))
